# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
datos  = pd.read_csv('Complaint_Attorney_2023_CDMX.csv')
datos
# Out:
#        idCarpeta  Año_inicio Mes_inicio FechaInicio
# 0        9361878        2023      Enero  2023-01-01  \
# 1        9361879        2023      Enero  2023-01-01
# 2        9361880        2023      Enero  2023-01-01
# 3        9361881        2023      Enero  2023-01-01
# 4        9361882        2023      Enero  2023-01-01
# ...          ...         ...        ...         ...
# 64339    9429532        2023      Marzo  2023-03-31
# 64340    9429533        2023      Marzo  2023-03-31
# 64341    9429534        2023      Marzo  2023-03-31
# 64342    9429535        2023      Marzo  2023-03-31
# 64343    9429536        2023      Marzo  2023-03-31
#
#                                                   Delito
# 0      LESIONES CULPOSAS POR TRANSITO VEHICULAR EN CO...  \
# 1         ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 2      ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VI...
# 3      LESIONES CULPOSAS POR TRANSITO VEHICULAR EN CO...
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64344 entries, 0 to 64343
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   idCarpeta             64344 non-null  int64
#  1   Año_inicio            64344 non-null  int64
#  2   Mes_inicio            64344 non-null  object
#  3   FechaInicio           64344 non-null  object
#  4   Delito                64344 non-null  object
#  5   Categoria             64344 non-null  object
#  6   Sexo                  54929 non-null  object
#  7   Edad                  44981 non-null  float64
#  8   TipoPersona           64212 non-null  object
#  9   CalidadJuridica       64344 non-null  object
#  10  competencia           64344 non-null  object
#  11  Año_hecho             64337 non-null  float64
#  12  Mes_hecho             64337 non-null  object
#  13  FechaHecho            64337 non-null  object
#  14  HoraHecho             64337 non-null  object
# ...

# %% [markdown]
# Tenemos un total de 64344 patrones, con 16 clases y un IR de: 93.93284671532847

# %%
ir = float(len(datos["Categoria"])/datos["municipio_hechos"].count())
print(ir)
# Out:
# 93.93284671532847
